# %%
from src.main.utils.plotter import histogram_bars, histogram_bars_grouped, merge_labels_2d, \
    draw_plot_point_label_set2, plot_on_one_errorbars, get_color, plot_on_one
import numpy as np

# %%
data = [1, 2, 3]
labels = ['a', 'b', 'c']
histogram_bars(data, labels)

# %%
data = [
    [1, 2, 3, 4],
    [2, 3, 4, 5],
    [2, 3, 4, 5]
]
xlabels = ['a', 'b', 'c', 'd'] 
bar_labels = ['bar1', 'bar2', 'bar3']

histogram_bars_grouped(data, xlabels, bar_labels)

# %%
original_set = merge_labels_2d(np.array([[1, 1], [2, 2], [3, 3]]), np.array([1, 2, 3]))
draw_plot_point_label_set2('original', 'x', 'y', original_set)

# %%
x = np.arange(10)
y1 = np.array([np.sin(i) for i in x]) 
y2 = y1 + 2
y_err = np.ones(10)/2

data = []
data.extend([x, y1, 'one', get_color(0) + '-', y_err])
data.extend([x, y2, 'two', get_color(1) + '-', y_err])
plot_on_one_errorbars('test', 'x', 'y', data, only_ints_on_x=True)

# %%
data = []
data.extend([x, y1, 'one', get_color(0) + '-'])
data.extend([x, y2, 'two', get_color(1) + '-'])
plot_on_one('test', 'x', 'y', data)
