# %%
from src.main.DatasetManager import DatasetManager
from src.main.Evaluator import Evaluator
from src.main.models.ClusteredItemBasedCF import ClusteredItemBasedCF
from src.main.models.ClusteredUserBasedCF import ClusteredUserBasedCF
from src.main.models.ItemBasedCF import ItemBasedCF
from src.main.models.UserBasedCF import UserBasedCF
from src.main.utils.plot_generators import gen_plots_with_errbars, measure_time, gen_grouped_histogram_bars
import numpy as np

# %%
dirname = '/home/damian/Pulpit/Warsztat/CoML/recomm_project/data/'
dm = DatasetManager()

# ml100k_filename = dirname + 'ml-100k/u.data'
# data = dm.load_csv(ml100k_filename, realative=False)
# train, test = dm.train_test_split(data, shuffle=False)
# 
# user_item = dm.transform_to_user_item_mat(train, verbose=True)
# user_item_test = dm.transform_to_user_item_mat(test, verbose=True)

# %%
ml100k_filename = dirname + 'ml-100k/ua.base'
ml100k_filename_test = dirname + 'ml-100k/ua.test'

train = dm.load_csv(ml100k_filename, realative=False)
test = dm.load_csv(ml100k_filename_test, realative=False)

user_item = DatasetManager.transform_to_user_item_mat(train, verbose=True)
user_item_test = DatasetManager.transform_to_user_item_mat(test, verbose=True)
# Out:
# User number: 943, item number: 1682
# User number: 943, item number: 1664

# %%
# eval metrics across different k neighbours

plots = [
    {'key': 'time', 'name': 'Prediction time x k-similar neighbours', 'xlabel': 'k', 'ylabel': 't [s]'},
    {'key': 'prec', 'name': 'Precision x k-similar neighbours', 'xlabel': 'k', 'ylabel': 'prec'},
    {'key': 'recall', 'name': 'Recall x k-similar neighbours', 'xlabel': 'k', 'ylabel': 'recall'},
    {'key': 'f1', 'name': 'F1 score x k-similar neighbours', 'xlabel': 'k', 'ylabel': 'f1'},
    {'key': 'rmse', 'name': 'RMSE x k-similar neighbours', 'xlabel': 'k', 'ylabel': 'rmse'},
    {'key': 'mae', 'name': 'MAE x k-similar neighbours', 'xlabel': 'k', 'ylabel': 'mae'}
]

models = [
    { 'model': UserBasedCF, 'name': 'UserBasedCF'},
    { 'model': ItemBasedCF, 'name': 'ItemBasedCF'},
    { 'model': ClusteredUserBasedCF, 'name': 'ClustUsrBasedCF'},
    { 'model': ClusteredItemBasedCF, 'name': 'ClustItmBasedCF'}
]

k_range = np.arange(1, 30)
repeat = 3

def func(sink, model_desc, k):
    model_class = model_desc['model']
    model = model_class(k_similar=k, verbose=True)
    
    # fit model 
    model.fit(user_item)
    
    # predict
    pred = measure_time(lambda: model.predict_all(), sink['time'])
    
    # recommend
    recomm, _ = model._recommend_all(pred)
    recomm = model._transform_recomm(recomm)

    # eval
    eval = Evaluator(user_item_test).eval(recomm, pred)
    
    sink['prec'].append(eval['prec'])
    sink['recall'].append(eval['recall'])
    sink['f1'].append(eval['f1'])
    sink['rmse'].append(eval['rmse'])
    sink['mae'].append(eval['mae'])

# %%
gen_plots_with_errbars(plots, models, k_range, func, repeat, verbose=True)
# Out:
# (0) started calculation for UserBasedCF case
# [UserBasedCF.fit] total 5.80 seconds have spent
#
# [UserBasedCF.predict_all] total 2.02 seconds have spent
#
# [UserBasedCF.fit] total 7.05 seconds have spent
#
# [UserBasedCF.predict_all] total 2.36 seconds have spent
#
# [UserBasedCF.fit] total 6.61 seconds have spent
#
# [UserBasedCF.predict_all] total 2.29 seconds have spent
#
# >>> results for value 1:
#   >>> time - y: 2.221444765726725, err: 0.1469505166911649
#   >>> prec - y: 0.029798515376458112, err: 0.0
#   >>> recall - y: 0.029798515376458112, err: 0.0
#   >>> f1 - y: 0.029798515376458112, err: 0.0
#   >>> rmse - y: 3.573364255952272, err: 0.0
#   >>> mae - y: 3.386586815927623, err: 0.0
# [UserBasedCF.fit] total 6.54 seconds have spent
#
# [UserBasedCF.predict_all] total 3.55 seconds have spent
#
# [UserBasedCF.fit] total 5.95 seconds have spent
#
# [UserBasedCF.predict_all] total 3.68 seconds have spent
#
# [UserBasedCF.fit] total 6.66 seconds have spent
#
# [UserBasedCF.predict_all] total 3.69 seconds have spent
#
# >>> results for value 2:
#   >>> time - y: 3.638305425643921, err: 0.06279156708761693
#   >>> prec - y: 0.12067868504772004, err: 0.0
#   >>> recall - y: 0.12067868504772004, err: 0.0
#   >>> f1 - y: 0.12067868504772004, err: 0.0
#   >>> rmse - y: 3.3297429526778917, err: 0.0
#   >>> mae - y: 3.1135117942186947, err: 0.0
# [UserBasedCF.fit] total 6.69 seconds have spent
#
# [UserBasedCF.predict_all] total 4.93 seconds have spent
#
# [UserBasedCF.fit] total 6.27 seconds have spent
#
# [UserBasedCF.predict_all] total 4.63 seconds have spent
#
# [UserBasedCF.fit] total 5.92 seconds have spent
#
# [UserBasedCF.predict_all] total 5.12 seconds have spent
#
# >>> results for value 3:
#   >>> time - y: 4.891344388326009, err: 0.1999844850111043
#   >>> prec - y: 0.14538706256627784, err: 0.0
#   >>> recall - y: 0.14538706256627784, err: 0.0
#   >>> f1 - y: 0.14538706256627784, err: 0.0
#   >>> rmse - y: 3.194013639938817, err: 0.0
#   >>> mae - y: 2.9603991392849793, err: 4.440892098500626e-16
# [UserBasedCF.fit] total 6.55 seconds have spent
#
# [UserBasedCF.predict_all] total 6.92 seconds have spent
#
# [UserBasedCF.fit] total 6.26 seconds have spent
#
# [UserBasedCF.predict_all] total 6.29 seconds have spent
#
# [UserBasedCF.fit] total 6.25 seconds have spent
#
# [UserBasedCF.predict_all] total 7.17 seconds have spent
#
# >>> results for value 4:
#   >>> time - y: 6.793182770411174, err: 0.3732611369421087
#   >>> prec - y: 0.1653234358430541, err: 0.0
#   >>> recall - y: 0.1653234358430541, err: 0.0
#   >>> f1 - y: 0.1653234358430541, err: 0.0
#   >>> rmse - y: 3.101047612164878, err: 4.440892098500626e-16
#   >>> mae - y: 2.8540120981752235, err: 0.0
# [UserBasedCF.fit] total 6.63 seconds have spent
#
# [UserBasedCF.predict_all] total 7.18 seconds have spent
#
# [UserBasedCF.fit] total 7.55 seconds have spent
#
# [UserBasedCF.predict_all] total 8.93 seconds have spent
#
# [UserBasedCF.fit] total 7.69 seconds have spent
#
# [UserBasedCF.predict_all] total 8.95 seconds have spent
#
# >>> results for value 5:
#   >>> time - y: 8.353318929672241, err: 0.8264671210284905
#   >>> prec - y: 0.17741251325556737, err: 2.7755575615628914e-17
#   >>> recall - y: 0.17741251325556737, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.17741251325556737, err: 2.7755575615628914e-17
#   >>> rmse - y: 3.0401830825959153, err: 0.0
#   >>> mae - y: 2.7837203392989576, err: 0.0
# [UserBasedCF.fit] total 6.25 seconds have spent
#
# [UserBasedCF.predict_all] total 9.66 seconds have spent
#
# [UserBasedCF.fit] total 6.63 seconds have spent
#
# [UserBasedCF.predict_all] total 10.47 seconds have spent
#
# [UserBasedCF.fit] total 6.36 seconds have spent
#
# [UserBasedCF.predict_all] total 9.77 seconds have spent
#
# >>> results for value 6:
#   >>> time - y: 9.965545813242594, err: 0.356870703433773
#   >>> prec - y: 0.1885471898197243, err: 0.0
#   >>> recall - y: 0.1885471898197243, err: 0.0
#   >>> f1 - y: 0.1885471898197243, err: 0.0
#   >>> rmse - y: 2.9895911221582474, err: 4.440892098500626e-16
#   >>> mae - y: 2.7276023225783868, err: 0.0
# [UserBasedCF.fit] total 6.34 seconds have spent
#
# [UserBasedCF.predict_all] total 12.87 seconds have spent
#
# [UserBasedCF.fit] total 6.37 seconds have spent
#
# [UserBasedCF.predict_all] total 10.70 seconds have spent
#
# [UserBasedCF.fit] total 5.54 seconds have spent
#
# [UserBasedCF.predict_all] total 12.12 seconds have spent
#
# >>> results for value 7:
#   >>> time - y: 11.896579504013062, err: 0.9030924524901882
#   >>> prec - y: 0.1968186638388123, err: 0.0
#   >>> recall - y: 0.1968186638388123, err: 0.0
#   >>> f1 - y: 0.1968186638388123, err: 0.0
#   >>> rmse - y: 2.95037428812136, err: 0.0
#   >>> mae - y: 2.6836006346364045, err: 4.440892098500626e-16
# [UserBasedCF.fit] total 6.10 seconds have spent
#
# [UserBasedCF.predict_all] total 13.83 seconds have spent
#
# [UserBasedCF.fit] total 7.24 seconds have spent
#
# [UserBasedCF.predict_all] total 14.97 seconds have spent
#
# [UserBasedCF.fit] total 5.87 seconds have spent
#
# [UserBasedCF.predict_all] total 13.32 seconds have spent
#
# >>> results for value 8:
#   >>> time - y: 14.042462984720865, err: 0.6897815418134401
#   >>> prec - y: 0.20328738069989397, err: 0.0
#   >>> recall - y: 0.20328738069989397, err: 0.0
#   >>> f1 - y: 0.20328738069989397, err: 0.0
#   >>> rmse - y: 2.9180735558088196, err: 0.0
#   >>> mae - y: 2.6469591282223317, err: 0.0
# [UserBasedCF.fit] total 6.74 seconds have spent
#
# [UserBasedCF.predict_all] total 14.36 seconds have spent
#
# [UserBasedCF.fit] total 5.41 seconds have spent
#
# [UserBasedCF.predict_all] total 13.61 seconds have spent
#
# [UserBasedCF.fit] total 7.03 seconds have spent
#
# [UserBasedCF.predict_all] total 12.45 seconds have spent
#
# >>> results for value 9:
#   >>> time - y: 13.472230434417725, err: 0.7868034287586602
#   >>> prec - y: 0.20477200424178155, err: 0.0
#   >>> recall - y: 0.20477200424178155, err: 0.0
#   >>> f1 - y: 0.20477200424178155, err: 0.0
#   >>> rmse - y: 2.891857454193536, err: 0.0
#   >>> mae - y: 2.6177785327487695, err: 0.0
# [UserBasedCF.fit] total 6.75 seconds have spent
#
# [UserBasedCF.predict_all] total 15.51 seconds have spent
#
# [UserBasedCF.fit] total 6.59 seconds have spent
#
# [UserBasedCF.predict_all] total 14.55 seconds have spent
#
# [UserBasedCF.fit] total 6.43 seconds have spent
#
# [UserBasedCF.predict_all] total 15.43 seconds have spent
#
# >>> results for value 10:
#   >>> time - y: 15.162458658218384, err: 0.4349402837448769
#   >>> prec - y: 0.20721102863202545, err: 0.0
#   >>> recall - y: 0.20721102863202545, err: 0.0
#   >>> f1 - y: 0.20721102863202545, err: 0.0
#   >>> rmse - y: 2.8705620095153095, err: 4.440892098500626e-16
#   >>> mae - y: 2.594477066179591, err: 0.0
# [UserBasedCF.fit] total 6.28 seconds have spent
#
# [UserBasedCF.predict_all] total 15.75 seconds have spent
#
# [UserBasedCF.fit] total 6.24 seconds have spent
#
# [UserBasedCF.predict_all] total 16.18 seconds have spent
#
# [UserBasedCF.fit] total 6.01 seconds have spent
#
# [UserBasedCF.predict_all] total 16.71 seconds have spent
#
# >>> results for value 11:
#   >>> time - y: 16.211127758026123, err: 0.3924610475002999
#   >>> prec - y: 0.21113467656415694, err: 0.0
#   >>> recall - y: 0.21113467656415694, err: 0.0
#   >>> f1 - y: 0.21113467656415694, err: 0.0
#   >>> rmse - y: 2.8510234184028547, err: 0.0
#   >>> mae - y: 2.573900406450436, err: 0.0
# [UserBasedCF.fit] total 6.92 seconds have spent
#
# [UserBasedCF.predict_all] total 19.24 seconds have spent
#
# [UserBasedCF.fit] total 6.90 seconds have spent
#
# [UserBasedCF.predict_all] total 19.29 seconds have spent
#
# [UserBasedCF.fit] total 5.98 seconds have spent
#
# [UserBasedCF.predict_all] total 22.92 seconds have spent
#
# >>> results for value 12:
#   >>> time - y: 20.482019901275635, err: 1.7206470563731322
#   >>> prec - y: 0.21474019088016968, err: 0.0
#   >>> recall - y: 0.21474019088016968, err: 0.0
#   >>> f1 - y: 0.21474019088016968, err: 0.0
#   >>> rmse - y: 2.8341231749894606, err: 0.0
#   >>> mae - y: 2.554968665828854, err: 0.0
# [UserBasedCF.fit] total 6.63 seconds have spent
#
# [UserBasedCF.predict_all] total 21.06 seconds have spent
#
# [UserBasedCF.fit] total 5.92 seconds have spent
#
# [UserBasedCF.predict_all] total 19.52 seconds have spent
#
# [UserBasedCF.fit] total 5.64 seconds have spent
#
# [UserBasedCF.predict_all] total 18.17 seconds have spent
#
# >>> results for value 13:
#   >>> time - y: 19.583966811498005, err: 1.1840360802483663
#   >>> prec - y: 0.21505832449628845, err: 0.0
#   >>> recall - y: 0.21505832449628845, err: 0.0
#   >>> f1 - y: 0.21505832449628845, err: 0.0
#   >>> rmse - y: 2.8203440344842003, err: 0.0
#   >>> mae - y: 2.540313548475635, err: 0.0
# [UserBasedCF.fit] total 7.94 seconds have spent
#
# [UserBasedCF.predict_all] total 20.11 seconds have spent
#
# [UserBasedCF.fit] total 7.02 seconds have spent
#
# [UserBasedCF.predict_all] total 20.31 seconds have spent
#
# [UserBasedCF.fit] total 5.77 seconds have spent
#
# [UserBasedCF.predict_all] total 19.75 seconds have spent
#
# >>> results for value 14:
#   >>> time - y: 20.058365027109783, err: 0.23371799422796022
#   >>> prec - y: 0.21696712619300107, err: 0.0
#   >>> recall - y: 0.21696712619300107, err: 0.0
#   >>> f1 - y: 0.21696712619300107, err: 0.0
#   >>> rmse - y: 2.8082998426949106, err: 0.0
#   >>> mae - y: 2.5273348037469865, err: 0.0
# [UserBasedCF.fit] total 5.80 seconds have spent
#
# [UserBasedCF.predict_all] total 19.70 seconds have spent
#
# [UserBasedCF.fit] total 5.19 seconds have spent
#
# [UserBasedCF.predict_all] total 19.96 seconds have spent
#
# [UserBasedCF.fit] total 5.12 seconds have spent
#
# [UserBasedCF.predict_all] total 19.31 seconds have spent
#
# >>> results for value 15:
#   >>> time - y: 19.653727451960247, err: 0.26682891510236145
#   >>> prec - y: 0.21866383881230114, err: 2.7755575615628914e-17
#   >>> recall - y: 0.21866383881230114, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.21866383881230114, err: 2.7755575615628914e-17
#   >>> rmse - y: 2.7985150885496695, err: 4.440892098500626e-16
#   >>> mae - y: 2.516152281037435, err: 0.0
# [UserBasedCF.fit] total 5.44 seconds have spent
#
# [UserBasedCF.predict_all] total 20.34 seconds have spent
#
# [UserBasedCF.fit] total 5.49 seconds have spent
#
# [UserBasedCF.predict_all] total 19.58 seconds have spent
#
# [UserBasedCF.fit] total 5.17 seconds have spent
#
# [UserBasedCF.predict_all] total 20.21 seconds have spent
#
# >>> results for value 16:
#   >>> time - y: 20.04275107383728, err: 0.3316329244314611
#   >>> prec - y: 0.2180275715800636, err: 2.7755575615628914e-17
#   >>> recall - y: 0.2180275715800636, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.21802757158006367, err: 0.0
#   >>> rmse - y: 2.7897260780790583, err: 0.0
#   >>> mae - y: 2.506532995572248, err: 0.0
# [UserBasedCF.fit] total 5.50 seconds have spent
#
# [UserBasedCF.predict_all] total 23.46 seconds have spent
#
# [UserBasedCF.fit] total 5.78 seconds have spent
#
# [UserBasedCF.predict_all] total 23.05 seconds have spent
#
# [UserBasedCF.fit] total 5.44 seconds have spent
#
# [UserBasedCF.predict_all] total 21.75 seconds have spent
#
# >>> results for value 17:
#   >>> time - y: 22.75633231798808, err: 0.7281465277203923
#   >>> prec - y: 0.2200424178154825, err: 0.0
#   >>> recall - y: 0.2200424178154825, err: 0.0
#   >>> f1 - y: 0.2200424178154825, err: 0.0
#   >>> rmse - y: 2.780902539152279, err: 0.0
#   >>> mae - y: 2.4967217005035987, err: 0.0
# [UserBasedCF.fit] total 5.45 seconds have spent
#
# [UserBasedCF.predict_all] total 23.43 seconds have spent
#
# [UserBasedCF.fit] total 5.17 seconds have spent
#
# [UserBasedCF.predict_all] total 23.86 seconds have spent
#
# [UserBasedCF.fit] total 5.56 seconds have spent
#
# [UserBasedCF.predict_all] total 24.07 seconds have spent
#
# >>> results for value 18:
#   >>> time - y: 23.787739276885986, err: 0.26558316092112527
#   >>> prec - y: 0.22078472958642634, err: 2.7755575615628914e-17
#   >>> recall - y: 0.22078472958642634, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.22078472958642634, err: 2.7755575615628914e-17
#   >>> rmse - y: 2.772578064928307, err: 0.0
#   >>> mae - y: 2.4878101898084175, err: 0.0
# [UserBasedCF.fit] total 5.58 seconds have spent
#
# [UserBasedCF.predict_all] total 26.54 seconds have spent
#
# [UserBasedCF.fit] total 5.68 seconds have spent
#
# [UserBasedCF.predict_all] total 25.20 seconds have spent
#
# [UserBasedCF.fit] total 5.65 seconds have spent
#
# [UserBasedCF.predict_all] total 25.06 seconds have spent
#
# >>> results for value 19:
#   >>> time - y: 25.600082794825237, err: 0.6695265527102066
#   >>> prec - y: 0.22279957582184517, err: 0.0
#   >>> recall - y: 0.22279957582184517, err: 0.0
#   >>> f1 - y: 0.2227995758218452, err: 0.0
#   >>> rmse - y: 2.7656025413258916, err: 4.440892098500626e-16
#   >>> mae - y: 2.480347746152749, err: 0.0
# [UserBasedCF.fit] total 5.47 seconds have spent
#
# [UserBasedCF.predict_all] total 26.84 seconds have spent
#
# [UserBasedCF.fit] total 5.52 seconds have spent
#
# [UserBasedCF.predict_all] total 26.12 seconds have spent
#
# [UserBasedCF.fit] total 5.77 seconds have spent
#
# [UserBasedCF.predict_all] total 25.19 seconds have spent
#
# >>> results for value 20:
#   >>> time - y: 26.050849676132202, err: 0.6746382940610677
#   >>> prec - y: 0.22311770943796394, err: 0.0
#   >>> recall - y: 0.22311770943796394, err: 0.0
#   >>> f1 - y: 0.22311770943796394, err: 0.0
#   >>> rmse - y: 2.7590386748049904, err: 0.0
#   >>> mae - y: 2.473235757817765, err: 0.0
# [UserBasedCF.fit] total 5.57 seconds have spent
#
# [UserBasedCF.predict_all] total 28.77 seconds have spent
#
# [UserBasedCF.fit] total 5.60 seconds have spent
#
# [UserBasedCF.predict_all] total 28.63 seconds have spent
#
# [UserBasedCF.fit] total 6.45 seconds have spent
#
# [UserBasedCF.predict_all] total 28.40 seconds have spent
#
# >>> results for value 21:
#   >>> time - y: 28.601002772649128, err: 0.15252249395213094
#   >>> prec - y: 0.22492046659597031, err: 0.0
#   >>> recall - y: 0.22492046659597031, err: 0.0
#   >>> f1 - y: 0.22492046659597031, err: 0.0
#   >>> rmse - y: 2.7528719129027728, err: 0.0
#   >>> mae - y: 2.4669877228779855, err: 0.0
# [UserBasedCF.fit] total 6.29 seconds have spent
#
# [UserBasedCF.predict_all] total 29.87 seconds have spent
#
# [UserBasedCF.fit] total 5.54 seconds have spent
#
# [UserBasedCF.predict_all] total 31.25 seconds have spent
#
# [UserBasedCF.fit] total 5.59 seconds have spent
#
# [UserBasedCF.predict_all] total 29.72 seconds have spent
#
# >>> results for value 22:
#   >>> time - y: 30.28171181678772, err: 0.6890098774183393
#   >>> prec - y: 0.22608695652173913, err: 0.0
#   >>> recall - y: 0.22608695652173913, err: 0.0
#   >>> f1 - y: 0.22608695652173913, err: 0.0
#   >>> rmse - y: 2.7460427970029215, err: 0.0
#   >>> mae - y: 2.4599287547559094, err: 0.0
# [UserBasedCF.fit] total 5.92 seconds have spent
#
# [UserBasedCF.predict_all] total 30.71 seconds have spent
#
# [UserBasedCF.fit] total 5.93 seconds have spent
#
# [UserBasedCF.predict_all] total 35.24 seconds have spent
#
# [UserBasedCF.fit] total 5.51 seconds have spent
#
# [UserBasedCF.predict_all] total 30.43 seconds have spent
#
# >>> results for value 23:
#   >>> time - y: 32.12788168589274, err: 2.2053987256121044
#   >>> prec - y: 0.22619300106044538, err: 0.0
#   >>> recall - y: 0.22619300106044538, err: 0.0
#   >>> f1 - y: 0.22619300106044538, err: 0.0
#   >>> rmse - y: 2.7407225138081075, err: 0.0
#   >>> mae - y: 2.4542077702487277, err: 0.0
# [UserBasedCF.fit] total 5.73 seconds have spent
#
# [UserBasedCF.predict_all] total 36.30 seconds have spent
#
# [UserBasedCF.fit] total 6.21 seconds have spent
#
# [UserBasedCF.predict_all] total 34.16 seconds have spent
#
# [UserBasedCF.fit] total 5.60 seconds have spent
#
# [UserBasedCF.predict_all] total 32.66 seconds have spent
#
# >>> results for value 24:
#   >>> time - y: 34.371524016062416, err: 1.4924640607084465
#   >>> prec - y: 0.22629904559915168, err: 2.7755575615628914e-17
#   >>> recall - y: 0.22629904559915168, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.22629904559915168, err: 2.7755575615628914e-17
#   >>> rmse - y: 2.7360300976687166, err: 0.0
#   >>> mae - y: 2.4494710312326298, err: 0.0
# [UserBasedCF.fit] total 5.63 seconds have spent
#
# [UserBasedCF.predict_all] total 34.54 seconds have spent
#
# [UserBasedCF.fit] total 5.67 seconds have spent
#
# [UserBasedCF.predict_all] total 32.76 seconds have spent
#
# [UserBasedCF.fit] total 5.62 seconds have spent
#
# [UserBasedCF.predict_all] total 32.05 seconds have spent
#
# >>> results for value 25:
#   >>> time - y: 33.11718805631002, err: 1.0470414081893182
#   >>> prec - y: 0.22502651113467656, err: 0.0
#   >>> recall - y: 0.22502651113467656, err: 0.0
#   >>> f1 - y: 0.22502651113467656, err: 0.0
#   >>> rmse - y: 2.7312862168098007, err: 4.440892098500626e-16
#   >>> mae - y: 2.4443397565976297, err: 0.0
# [UserBasedCF.fit] total 5.48 seconds have spent
#
# [UserBasedCF.predict_all] total 33.36 seconds have spent
#
# [UserBasedCF.fit] total 5.58 seconds have spent
#
# [UserBasedCF.predict_all] total 34.14 seconds have spent
#
# [UserBasedCF.fit] total 5.60 seconds have spent
#
# [UserBasedCF.predict_all] total 33.56 seconds have spent
#
# >>> results for value 26:
#   >>> time - y: 33.68412812550863, err: 0.3304466992772473
#   >>> prec - y: 0.2254506892895016, err: 0.0
#   >>> recall - y: 0.2254506892895016, err: 0.0
#   >>> f1 - y: 0.2254506892895016, err: 0.0
#   >>> rmse - y: 2.72728634052304, err: 0.0
#   >>> mae - y: 2.440329172931373, err: 0.0
# [UserBasedCF.fit] total 5.61 seconds have spent
#
# [UserBasedCF.predict_all] total 35.68 seconds have spent
#
# [UserBasedCF.fit] total 5.49 seconds have spent
#
# [UserBasedCF.predict_all] total 37.95 seconds have spent
#
# [UserBasedCF.fit] total 5.42 seconds have spent
#
# [UserBasedCF.predict_all] total 36.79 seconds have spent
#
# >>> results for value 27:
#   >>> time - y: 36.8064595858256, err: 0.9290465232543108
#   >>> prec - y: 0.2256627783669141, err: 0.0
#   >>> recall - y: 0.2256627783669141, err: 0.0
#   >>> f1 - y: 0.2256627783669141, err: 0.0
#   >>> rmse - y: 2.7234032560144397, err: 0.0
#   >>> mae - y: 2.4365278991390644, err: 0.0
# [UserBasedCF.fit] total 5.76 seconds have spent
#
# [UserBasedCF.predict_all] total 37.14 seconds have spent
#
# [UserBasedCF.fit] total 5.51 seconds have spent
#
# [UserBasedCF.predict_all] total 38.47 seconds have spent
#
# [UserBasedCF.fit] total 5.58 seconds have spent
#
# [UserBasedCF.predict_all] total 36.73 seconds have spent
#
# >>> results for value 28:
#   >>> time - y: 37.44717367490133, err: 0.7456433997851145
#   >>> prec - y: 0.22619300106044538, err: 0.0
#   >>> recall - y: 0.22619300106044538, err: 0.0
#   >>> f1 - y: 0.22619300106044538, err: 0.0
#   >>> rmse - y: 2.719864084902437, err: 0.0
#   >>> mae - y: 2.433061340910081, err: 0.0
# [UserBasedCF.fit] total 5.49 seconds have spent
#
# [UserBasedCF.predict_all] total 40.64 seconds have spent
#
# [UserBasedCF.fit] total 5.66 seconds have spent
#
# [UserBasedCF.predict_all] total 39.02 seconds have spent
#
# [UserBasedCF.fit] total 5.60 seconds have spent
#
# [UserBasedCF.predict_all] total 39.57 seconds have spent
#
# >>> results for value 29:
#   >>> time - y: 39.74369899431864, err: 0.6745211819945218
#   >>> prec - y: 0.2244962884411453, err: 2.7755575615628914e-17
#   >>> recall - y: 0.2244962884411453, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.2244962884411453, err: 2.7755575615628914e-17
#   >>> rmse - y: 2.714834916509428, err: 0.0
#   >>> mae - y: 2.428082863630599, err: 0.0
# (1) started calculation for ItemBasedCF case
# [ItemBasedCF.fit] total 24.23 seconds have spent
#
# [ItemBasedCF.predict_all] total 1.72 seconds have spent
#
# [ItemBasedCF.fit] total 24.27 seconds have spent
#
# [ItemBasedCF.predict_all] total 1.71 seconds have spent
#
# [ItemBasedCF.fit] total 24.48 seconds have spent
#
# [ItemBasedCF.predict_all] total 1.73 seconds have spent
#
# >>> results for value 1:
#   >>> time - y: 1.7189403374989827, err: 0.010394895362383577
#   >>> prec - y: 0.1088016967126193, err: 0.0
#   >>> recall - y: 0.1088016967126193, err: 0.0
#   >>> f1 - y: 0.1088016967126193, err: 0.0
#   >>> rmse - y: 3.142713002614658, err: 0.0
#   >>> mae - y: 2.940207590899693, err: 0.0
# [ItemBasedCF.fit] total 24.38 seconds have spent
#
# [ItemBasedCF.predict_all] total 2.48 seconds have spent
#
# [ItemBasedCF.fit] total 24.34 seconds have spent
#
# [ItemBasedCF.predict_all] total 2.44 seconds have spent
#
# [ItemBasedCF.fit] total 24.68 seconds have spent
#
# [ItemBasedCF.predict_all] total 2.45 seconds have spent
#
# >>> results for value 2:
#   >>> time - y: 2.4563953081766763, err: 0.014696378000047822
#   >>> prec - y: 0.1582184517497349, err: 0.0
#   >>> recall - y: 0.1582184517497349, err: 0.0
#   >>> f1 - y: 0.1582184517497349, err: 0.0
#   >>> rmse - y: 2.9363732044207, err: 0.0
#   >>> mae - y: 2.6613783968164224, err: 0.0
# [ItemBasedCF.fit] total 24.48 seconds have spent
#
# [ItemBasedCF.predict_all] total 3.20 seconds have spent
#
# [ItemBasedCF.fit] total 24.67 seconds have spent
#
# [ItemBasedCF.predict_all] total 3.18 seconds have spent
#
# [ItemBasedCF.fit] total 24.25 seconds have spent
#
# [ItemBasedCF.predict_all] total 3.22 seconds have spent
#
# >>> results for value 3:
#   >>> time - y: 3.201045195261637, err: 0.01817225277807559
#   >>> prec - y: 0.18441145281018026, err: 2.7755575615628914e-17
#   >>> recall - y: 0.18441145281018026, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.18441145281018026, err: 0.0
#   >>> rmse - y: 2.8969613973636696, err: 0.0
#   >>> mae - y: 2.5866816579726546, err: 0.0
# [ItemBasedCF.fit] total 24.60 seconds have spent
#
# [ItemBasedCF.predict_all] total 3.92 seconds have spent
#
# [ItemBasedCF.fit] total 24.34 seconds have spent
#
# [ItemBasedCF.predict_all] total 3.87 seconds have spent
#
# [ItemBasedCF.fit] total 24.77 seconds have spent
#
# [ItemBasedCF.predict_all] total 3.88 seconds have spent
#
# >>> results for value 4:
#   >>> time - y: 3.89239772160848, err: 0.019035461795769745
#   >>> prec - y: 0.19225874867444326, err: 0.0
#   >>> recall - y: 0.19225874867444326, err: 0.0
#   >>> f1 - y: 0.19225874867444323, err: 0.0
#   >>> rmse - y: 2.8757727238219606, err: 0.0
#   >>> mae - y: 2.5453579771914114, err: 0.0
# [ItemBasedCF.fit] total 26.15 seconds have spent
#
# [ItemBasedCF.predict_all] total 4.93 seconds have spent
#
# [ItemBasedCF.fit] total 24.74 seconds have spent
#
# [ItemBasedCF.predict_all] total 4.69 seconds have spent
#
# [ItemBasedCF.fit] total 25.02 seconds have spent
#
# [ItemBasedCF.predict_all] total 4.61 seconds have spent
#
# >>> results for value 5:
#   >>> time - y: 4.746954123179118, err: 0.13587896438989194
#   >>> prec - y: 0.19257688229056202, err: 0.0
#   >>> recall - y: 0.19257688229056202, err: 0.0
#   >>> f1 - y: 0.19257688229056202, err: 0.0
#   >>> rmse - y: 2.8347724008551034, err: 4.440892098500626e-16
#   >>> mae - y: 2.510965901420196, err: 0.0
# [ItemBasedCF.fit] total 24.57 seconds have spent
#
# [ItemBasedCF.predict_all] total 5.05 seconds have spent
#
# [ItemBasedCF.fit] total 24.16 seconds have spent
#
# [ItemBasedCF.predict_all] total 5.18 seconds have spent
#
# [ItemBasedCF.fit] total 24.66 seconds have spent
#
# [ItemBasedCF.predict_all] total 5.41 seconds have spent
#
# >>> results for value 6:
#   >>> time - y: 5.21484096844991, err: 0.15060822271264185
#   >>> prec - y: 0.19522799575821845, err: 0.0
#   >>> recall - y: 0.19522799575821845, err: 0.0
#   >>> f1 - y: 0.19522799575821845, err: 0.0
#   >>> rmse - y: 2.809775100053583, err: 4.440892098500626e-16
#   >>> mae - y: 2.4904530244230956, err: 0.0
# [ItemBasedCF.fit] total 25.96 seconds have spent
#
# [ItemBasedCF.predict_all] total 6.06 seconds have spent
#
# [ItemBasedCF.fit] total 24.84 seconds have spent
#
# [ItemBasedCF.predict_all] total 6.50 seconds have spent
#
# [ItemBasedCF.fit] total 24.56 seconds have spent
#
# [ItemBasedCF.predict_all] total 6.13 seconds have spent
#
# >>> results for value 7:
#   >>> time - y: 6.228668689727783, err: 0.19044332990089943
#   >>> prec - y: 0.1943796394485684, err: 0.0
#   >>> recall - y: 0.1943796394485684, err: 0.0
#   >>> f1 - y: 0.1943796394485684, err: 0.0
#   >>> rmse - y: 2.7837103750294108, err: 0.0
#   >>> mae - y: 2.4681698429167342, err: 0.0
# [ItemBasedCF.fit] total 24.24 seconds have spent
#
# [ItemBasedCF.predict_all] total 6.26 seconds have spent
#
# [ItemBasedCF.fit] total 23.25 seconds have spent
#
# [ItemBasedCF.predict_all] total 6.44 seconds have spent
#
# [ItemBasedCF.fit] total 22.71 seconds have spent
#
# [ItemBasedCF.predict_all] total 6.21 seconds have spent
#
# >>> results for value 8:
#   >>> time - y: 6.303172747294108, err: 0.09798238856640792
#   >>> prec - y: 0.19628844114528102, err: 0.0
#   >>> recall - y: 0.19628844114528102, err: 0.0
#   >>> f1 - y: 0.19628844114528102, err: 0.0
#   >>> rmse - y: 2.765887522276094, err: 4.440892098500626e-16
#   >>> mae - y: 2.4495042593981924, err: 0.0
# [ItemBasedCF.fit] total 23.45 seconds have spent
#
# [ItemBasedCF.predict_all] total 6.91 seconds have spent
#
# [ItemBasedCF.fit] total 23.08 seconds have spent
#
# [ItemBasedCF.predict_all] total 7.07 seconds have spent
#
# [ItemBasedCF.fit] total 22.42 seconds have spent
#
# [ItemBasedCF.predict_all] total 6.81 seconds have spent
#
# >>> results for value 9:
#   >>> time - y: 6.929321209589641, err: 0.10614205400226337
#   >>> prec - y: 0.19936373276776245, err: 0.0
#   >>> recall - y: 0.19936373276776245, err: 0.0
#   >>> f1 - y: 0.19936373276776245, err: 0.0
#   >>> rmse - y: 2.7481769316376137, err: 4.440892098500626e-16
#   >>> mae - y: 2.433711884425167, err: 0.0
# [ItemBasedCF.fit] total 23.45 seconds have spent
#
# [ItemBasedCF.predict_all] total 7.87 seconds have spent
#
# [ItemBasedCF.fit] total 22.77 seconds have spent
#
# [ItemBasedCF.predict_all] total 7.75 seconds have spent
#
# [ItemBasedCF.fit] total 22.81 seconds have spent
#
# [ItemBasedCF.predict_all] total 7.45 seconds have spent
#
# >>> results for value 10:
#   >>> time - y: 7.690453211466472, err: 0.1773353420674286
#   >>> prec - y: 0.1972428419936373, err: 2.7755575615628914e-17
#   >>> recall - y: 0.1972428419936373, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.1972428419936373, err: 0.0
#   >>> rmse - y: 2.741901172726246, err: 0.0
#   >>> mae - y: 2.4291535095105226, err: 0.0
# [ItemBasedCF.fit] total 23.29 seconds have spent
#
# [ItemBasedCF.predict_all] total 8.30 seconds have spent
#
# [ItemBasedCF.fit] total 22.58 seconds have spent
#
# [ItemBasedCF.predict_all] total 8.17 seconds have spent
#
# [ItemBasedCF.fit] total 22.88 seconds have spent
#
# [ItemBasedCF.predict_all] total 8.26 seconds have spent
#
# >>> results for value 11:
#   >>> time - y: 8.243637402852377, err: 0.054409948533149725
#   >>> prec - y: 0.19597030752916225, err: 0.0
#   >>> recall - y: 0.19597030752916225, err: 0.0
#   >>> f1 - y: 0.19597030752916225, err: 0.0
#   >>> rmse - y: 2.73639834180107, err: 0.0
#   >>> mae - y: 2.424154376304905, err: 0.0
# [ItemBasedCF.fit] total 24.39 seconds have spent
#
# [ItemBasedCF.predict_all] total 9.19 seconds have spent
#
# [ItemBasedCF.fit] total 23.52 seconds have spent
#
# [ItemBasedCF.predict_all] total 9.29 seconds have spent
#
# [ItemBasedCF.fit] total 23.42 seconds have spent
#
# [ItemBasedCF.predict_all] total 9.70 seconds have spent
#
# >>> results for value 12:
#   >>> time - y: 9.391499201456705, err: 0.2198782665667271
#   >>> prec - y: 0.19575821845174976, err: 2.7755575615628914e-17
#   >>> recall - y: 0.19575821845174976, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.19575821845174976, err: 2.7755575615628914e-17
#   >>> rmse - y: 2.7314774809193865, err: 0.0
#   >>> mae - y: 2.418153039609253, err: 0.0
# [ItemBasedCF.fit] total 24.63 seconds have spent
#
# [ItemBasedCF.predict_all] total 10.80 seconds have spent
#
# [ItemBasedCF.fit] total 24.73 seconds have spent
#
# [ItemBasedCF.predict_all] total 10.55 seconds have spent
#
# [ItemBasedCF.fit] total 24.84 seconds have spent
#
# [ItemBasedCF.predict_all] total 10.96 seconds have spent
#
# >>> results for value 13:
#   >>> time - y: 10.772068421045939, err: 0.16936981663577028
#   >>> prec - y: 0.19660657476139978, err: 0.0
#   >>> recall - y: 0.19660657476139978, err: 0.0
#   >>> f1 - y: 0.19660657476139978, err: 0.0
#   >>> rmse - y: 2.7219875358999612, err: 0.0
#   >>> mae - y: 2.409235175658274, err: 0.0
# [ItemBasedCF.fit] total 25.15 seconds have spent
#
# [ItemBasedCF.predict_all] total 12.40 seconds have spent
#
# [ItemBasedCF.fit] total 25.46 seconds have spent
#
# [ItemBasedCF.predict_all] total 11.06 seconds have spent
#
# [ItemBasedCF.fit] total 26.04 seconds have spent
#
# [ItemBasedCF.predict_all] total 10.95 seconds have spent
#
# >>> results for value 14:
#   >>> time - y: 11.469577868779501, err: 0.6610100879636053
#   >>> prec - y: 0.19501590668080593, err: 0.0
#   >>> recall - y: 0.19501590668080593, err: 0.0
#   >>> f1 - y: 0.19501590668080593, err: 0.0
#   >>> rmse - y: 2.7182335782055893, err: 4.440892098500626e-16
#   >>> mae - y: 2.4055007702141866, err: 0.0
# [ItemBasedCF.fit] total 24.42 seconds have spent
#
# [ItemBasedCF.predict_all] total 11.97 seconds have spent
#
# [ItemBasedCF.fit] total 26.61 seconds have spent
#
# [ItemBasedCF.predict_all] total 12.93 seconds have spent
#
# [ItemBasedCF.fit] total 25.04 seconds have spent
#
# [ItemBasedCF.predict_all] total 12.88 seconds have spent
#
# >>> results for value 15:
#   >>> time - y: 12.593493461608887, err: 0.43993575254870376
#   >>> prec - y: 0.19225874867444326, err: 0.0
#   >>> recall - y: 0.19225874867444326, err: 0.0
#   >>> f1 - y: 0.19225874867444323, err: 0.0
#   >>> rmse - y: 2.7132902924492464, err: 4.440892098500626e-16
#   >>> mae - y: 2.4010626563313844, err: 0.0
# [ItemBasedCF.fit] total 27.08 seconds have spent
#
# [ItemBasedCF.predict_all] total 13.18 seconds have spent
#
# [ItemBasedCF.fit] total 25.21 seconds have spent
#
# [ItemBasedCF.predict_all] total 13.21 seconds have spent
#
# [ItemBasedCF.fit] total 24.75 seconds have spent
#
# [ItemBasedCF.predict_all] total 12.76 seconds have spent
#
# >>> results for value 16:
#   >>> time - y: 13.048669815063477, err: 0.2070891598617828
#   >>> prec - y: 0.19162248144220573, err: 0.0
#   >>> recall - y: 0.19162248144220573, err: 0.0
#   >>> f1 - y: 0.19162248144220573, err: 0.0
#   >>> rmse - y: 2.709309050385793, err: 4.440892098500626e-16
#   >>> mae - y: 2.3985385733848648, err: 0.0
# [ItemBasedCF.fit] total 24.92 seconds have spent
#
# [ItemBasedCF.predict_all] total 13.34 seconds have spent
#
# [ItemBasedCF.fit] total 24.17 seconds have spent
#
# [ItemBasedCF.predict_all] total 14.68 seconds have spent
#
# [ItemBasedCF.fit] total 24.52 seconds have spent
#
# [ItemBasedCF.predict_all] total 14.09 seconds have spent
#
# >>> results for value 17:
#   >>> time - y: 14.034825166066488, err: 0.5491912522844117
#   >>> prec - y: 0.1906680805938494, err: 0.0
#   >>> recall - y: 0.1906680805938494, err: 0.0
#   >>> f1 - y: 0.1906680805938494, err: 0.0
#   >>> rmse - y: 2.7040828175970972, err: 0.0
#   >>> mae - y: 2.394596509234413, err: 0.0
# [ItemBasedCF.fit] total 25.11 seconds have spent
#
# [ItemBasedCF.predict_all] total 13.80 seconds have spent
#
# [ItemBasedCF.fit] total 24.10 seconds have spent
#
# [ItemBasedCF.predict_all] total 14.41 seconds have spent
#
# [ItemBasedCF.fit] total 23.82 seconds have spent
#
# [ItemBasedCF.predict_all] total 15.40 seconds have spent
#
# >>> results for value 18:
#   >>> time - y: 14.53659987449646, err: 0.6579487514836997
#   >>> prec - y: 0.1899257688229056, err: 2.7755575615628914e-17
#   >>> recall - y: 0.1899257688229056, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.1899257688229056, err: 2.7755575615628914e-17
#   >>> rmse - y: 2.6984163502094165, err: 0.0
#   >>> mae - y: 2.3890034409241516, err: 0.0
# [ItemBasedCF.fit] total 23.68 seconds have spent
#
# [ItemBasedCF.predict_all] total 14.06 seconds have spent
#
# [ItemBasedCF.fit] total 24.14 seconds have spent
#
# [ItemBasedCF.predict_all] total 13.93 seconds have spent
#
# [ItemBasedCF.fit] total 23.57 seconds have spent
#
# [ItemBasedCF.predict_all] total 13.98 seconds have spent
#
# >>> results for value 19:
#   >>> time - y: 13.991715987523397, err: 0.054458794825529094
#   >>> prec - y: 0.18886532343584306, err: 0.0
#   >>> recall - y: 0.18886532343584306, err: 0.0
#   >>> f1 - y: 0.18886532343584306, err: 0.0
#   >>> rmse - y: 2.6945228043511364, err: 0.0
#   >>> mae - y: 2.385093047951344, err: 0.0
# [ItemBasedCF.fit] total 23.94 seconds have spent
#
# [ItemBasedCF.predict_all] total 14.81 seconds have spent
#
# [ItemBasedCF.fit] total 23.68 seconds have spent
#
# [ItemBasedCF.predict_all] total 14.43 seconds have spent
#
# [ItemBasedCF.fit] total 24.08 seconds have spent
#
# [ItemBasedCF.predict_all] total 14.59 seconds have spent
#
# >>> results for value 20:
#   >>> time - y: 14.611003160476685, err: 0.15229661742714595
#   >>> prec - y: 0.1896076352067869, err: 2.7755575615628914e-17
#   >>> recall - y: 0.1896076352067869, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.18960763520678683, err: 0.0
#   >>> rmse - y: 2.692889455488914, err: 0.0
#   >>> mae - y: 2.383996843866765, err: 0.0
# [ItemBasedCF.fit] total 23.66 seconds have spent
#
# [ItemBasedCF.predict_all] total 15.32 seconds have spent
#
# [ItemBasedCF.fit] total 23.43 seconds have spent
#
# [ItemBasedCF.predict_all] total 15.18 seconds have spent
#
# [ItemBasedCF.fit] total 23.73 seconds have spent
#
# [ItemBasedCF.predict_all] total 15.07 seconds have spent
#
# >>> results for value 21:
#   >>> time - y: 15.188592592875162, err: 0.10141752029524846
#   >>> prec - y: 0.18716861081654299, err: 2.7755575615628914e-17
#   >>> recall - y: 0.18716861081654299, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.18716861081654299, err: 0.0
#   >>> rmse - y: 2.6920590668267406, err: 0.0
#   >>> mae - y: 2.3840370846866996, err: 0.0
# [ItemBasedCF.fit] total 23.82 seconds have spent
#
# [ItemBasedCF.predict_all] total 16.05 seconds have spent
#
# [ItemBasedCF.fit] total 23.73 seconds have spent
#
# [ItemBasedCF.predict_all] total 16.01 seconds have spent
#
# [ItemBasedCF.fit] total 24.00 seconds have spent
#
# [ItemBasedCF.predict_all] total 15.66 seconds have spent
#
# >>> results for value 22:
#   >>> time - y: 15.905527671178183, err: 0.17567037632839602
#   >>> prec - y: 0.18642629904559915, err: 0.0
#   >>> recall - y: 0.18642629904559915, err: 0.0
#   >>> f1 - y: 0.18642629904559918, err: 0.0
#   >>> rmse - y: 2.688358983173489, err: 4.440892098500626e-16
#   >>> mae - y: 2.38091287780106, err: 0.0
# [ItemBasedCF.fit] total 23.48 seconds have spent
#
# [ItemBasedCF.predict_all] total 16.91 seconds have spent
#
# [ItemBasedCF.fit] total 25.43 seconds have spent
#
# [ItemBasedCF.predict_all] total 16.69 seconds have spent
#
# [ItemBasedCF.fit] total 24.04 seconds have spent
#
# [ItemBasedCF.predict_all] total 16.37 seconds have spent
#
# >>> results for value 23:
#   >>> time - y: 16.653982321421307, err: 0.22136728727673446
#   >>> prec - y: 0.18525980911983034, err: 0.0
#   >>> recall - y: 0.18525980911983034, err: 0.0
#   >>> f1 - y: 0.18525980911983034, err: 0.0
#   >>> rmse - y: 2.6857866300510316, err: 0.0
#   >>> mae - y: 2.378865379327302, err: 0.0
# [ItemBasedCF.fit] total 23.96 seconds have spent
#
# [ItemBasedCF.predict_all] total 17.53 seconds have spent
#
# [ItemBasedCF.fit] total 23.74 seconds have spent
#
# [ItemBasedCF.predict_all] total 17.60 seconds have spent
#
# [ItemBasedCF.fit] total 23.59 seconds have spent
#
# [ItemBasedCF.predict_all] total 17.54 seconds have spent
#
# >>> results for value 24:
#   >>> time - y: 17.555528322855633, err: 0.029779194844363265
#   >>> prec - y: 0.184305408271474, err: 0.0
#   >>> recall - y: 0.184305408271474, err: 0.0
#   >>> f1 - y: 0.18430540827147399, err: 0.0
#   >>> rmse - y: 2.6834212083590514, err: 0.0
#   >>> mae - y: 2.376974518888407, err: 0.0
# [ItemBasedCF.fit] total 23.76 seconds have spent
#
# [ItemBasedCF.predict_all] total 18.33 seconds have spent
#
# [ItemBasedCF.fit] total 23.60 seconds have spent
#
# [ItemBasedCF.predict_all] total 18.13 seconds have spent
#
# [ItemBasedCF.fit] total 25.13 seconds have spent
#
# [ItemBasedCF.predict_all] total 18.56 seconds have spent
#
# >>> results for value 25:
#   >>> time - y: 18.34170126914978, err: 0.1769577348098533
#   >>> prec - y: 0.18419936373276777, err: 0.0
#   >>> recall - y: 0.18419936373276777, err: 0.0
#   >>> f1 - y: 0.18419936373276777, err: 0.0
#   >>> rmse - y: 2.681304140435224, err: 0.0
#   >>> mae - y: 2.3755608233533896, err: 0.0
# [ItemBasedCF.fit] total 22.68 seconds have spent
#
# [ItemBasedCF.predict_all] total 17.69 seconds have spent
#
# [ItemBasedCF.fit] total 22.68 seconds have spent
#
# [ItemBasedCF.predict_all] total 18.87 seconds have spent
#
# [ItemBasedCF.fit] total 25.40 seconds have spent
#
# [ItemBasedCF.predict_all] total 18.20 seconds have spent
#
# >>> results for value 26:
#   >>> time - y: 18.25357747077942, err: 0.48443206029700636
#   >>> prec - y: 0.18197242841993636, err: 2.7755575615628914e-17
#   >>> recall - y: 0.18197242841993636, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.18197242841993636, err: 2.7755575615628914e-17
#   >>> rmse - y: 2.681483482705268, err: 0.0
#   >>> mae - y: 2.376183637856108, err: 0.0
# [ItemBasedCF.fit] total 22.22 seconds have spent
#
# [ItemBasedCF.predict_all] total 18.34 seconds have spent
#
# [ItemBasedCF.fit] total 22.29 seconds have spent
#
# [ItemBasedCF.predict_all] total 18.51 seconds have spent
#
# [ItemBasedCF.fit] total 22.26 seconds have spent
#
# [ItemBasedCF.predict_all] total 18.20 seconds have spent
#
# >>> results for value 27:
#   >>> time - y: 18.3531334400177, err: 0.12729974653502169
#   >>> prec - y: 0.1806998939554613, err: 0.0
#   >>> recall - y: 0.1806998939554613, err: 0.0
#   >>> f1 - y: 0.1806998939554613, err: 0.0
#   >>> rmse - y: 2.680610864897224, err: 4.440892098500626e-16
#   >>> mae - y: 2.3756345615229115, err: 0.0
# [ItemBasedCF.fit] total 22.60 seconds have spent
#
# [ItemBasedCF.predict_all] total 19.08 seconds have spent
#
# [ItemBasedCF.fit] total 22.75 seconds have spent
#
# [ItemBasedCF.predict_all] total 18.95 seconds have spent
#
# [ItemBasedCF.fit] total 22.77 seconds have spent
#
# [ItemBasedCF.predict_all] total 19.08 seconds have spent
#
# >>> results for value 28:
#   >>> time - y: 19.03593365351359, err: 0.05883132153529501
#   >>> prec - y: 0.17953340402969245, err: 2.7755575615628914e-17
#   >>> recall - y: 0.17953340402969245, err: 2.7755575615628914e-17
#   >>> f1 - y: 0.17953340402969245, err: 2.7755575615628914e-17
#   >>> rmse - y: 2.680234792681197, err: 0.0
#   >>> mae - y: 2.375830808137892, err: 0.0
# [ItemBasedCF.fit] total 22.95 seconds have spent
#
# [ItemBasedCF.predict_all] total 19.98 seconds have spent
#
# [ItemBasedCF.fit] total 22.26 seconds have spent
#
# [ItemBasedCF.predict_all] total 19.94 seconds have spent
#
# [ItemBasedCF.fit] total 22.40 seconds have spent
#
# [ItemBasedCF.predict_all] total 19.67 seconds have spent
#
# >>> results for value 29:
#   >>> time - y: 19.86342986424764, err: 0.13669301213920396
#   >>> prec - y: 0.179745493107105, err: 0.0
#   >>> recall - y: 0.179745493107105, err: 0.0
#   >>> f1 - y: 0.179745493107105, err: 0.0
#   >>> rmse - y: 2.6797019837849803, err: 0.0
#   >>> mae - y: 2.3757861699572262, err: 0.0
# (2) started calculation for ClustUsrBasedCF case
# [ClusteredUserBasedCF._clusterize] total 1.07 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.87 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.94 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 1.52 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.90 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.83 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.73 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 1.48 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.04 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.94 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.97 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 1.48 seconds have spent
#
# >>> results for value 1:
#   >>> time - y: 1.4945120016733806, err: 0.02101595453641342
#   >>> prec - y: 0.12000706963591375, err: 0.0013310830953526171
#   >>> recall - y: 0.12000706963591375, err: 0.0013310830953526171
#   >>> f1 - y: 0.12000706963591375, err: 0.0013310830953526171
#   >>> rmse - y: 3.0184013411191795, err: 0.0014025056979730351
#   >>> mae - y: 2.5917410092262396, err: 0.00013781183310655922
# [ClusteredUserBasedCF._clusterize] total 0.99 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.80 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.80 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 2.55 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.92 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 3.11 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 4.03 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 2.84 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.04 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.73 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.77 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 2.52 seconds have spent
#
# >>> results for value 2:
#   >>> time - y: 2.640077749888102, err: 0.1441521366148907
#   >>> prec - y: 0.14694238246730293, err: 0.00013226077719243236
#   >>> recall - y: 0.14694238246730293, err: 0.00013226077719243236
#   >>> f1 - y: 0.14694238246730293, err: 0.00013226077719243236
#   >>> rmse - y: 2.845849365204162, err: 0.0011212052108597814
#   >>> mae - y: 2.4630229403244974, err: 0.0012956268420965193
# [ClusteredUserBasedCF._clusterize] total 1.03 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.71 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.75 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 3.85 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.98 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.74 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.72 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 3.77 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.97 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.81 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.79 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 3.94 seconds have spent
#
# >>> results for value 3:
#   >>> time - y: 3.853399117787679, err: 0.07210503220710905
#   >>> prec - y: 0.1622834924001414, err: 0.0013997164986372058
#   >>> recall - y: 0.1622834924001414, err: 0.0013997164986372058
#   >>> f1 - y: 0.1622834924001414, err: 0.0013997164986372058
#   >>> rmse - y: 2.784213467744495, err: 0.0024386046414288307
#   >>> mae - y: 2.4196149640510787, err: 0.0014118490723923538
# [ClusteredUserBasedCF._clusterize] total 0.89 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.58 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.48 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 5.17 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.09 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.65 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.74 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 4.99 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.01 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.57 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.58 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 4.94 seconds have spent
#
# >>> results for value 4:
#   >>> time - y: 5.03201953570048, err: 0.09989111765433034
#   >>> prec - y: 0.17447861435136092, err: 0.00039991899961063
#   >>> recall - y: 0.17447861435136092, err: 0.00039991899961063
#   >>> f1 - y: 0.17447861435136092, err: 0.00039991899961063
#   >>> rmse - y: 2.761709747325091, err: 0.0015251385699318876
#   >>> mae - y: 2.4057290515409373, err: 0.0005576698912620353
# [ClusteredUserBasedCF._clusterize] total 1.09 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.64 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.73 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 6.25 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.83 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.68 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.51 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 6.12 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.82 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.86 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.69 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 6.38 seconds have spent
#
# >>> results for value 5:
#   >>> time - y: 6.252946933110555, err: 0.10686926701068172
#   >>> prec - y: 0.1838458819370802, err: 0.0013862616861878877
#   >>> recall - y: 0.1838458819370802, err: 0.0013862616861878877
#   >>> f1 - y: 0.18384588193708026, err: 0.0013862616861878767
#   >>> rmse - y: 2.7394608412860073, err: 0.003024372983800982
#   >>> mae - y: 2.3958361705030486, err: 0.0021884832201419864
# [ClusteredUserBasedCF._clusterize] total 0.97 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.84 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.81 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 7.56 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.01 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.65 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.66 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 7.64 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.06 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.82 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.89 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 7.65 seconds have spent
#
# >>> results for value 6:
#   >>> time - y: 7.617128133773804, err: 0.04276522697166995
#   >>> prec - y: 0.19077412513255568, err: 0.00014996962485399769
#   >>> recall - y: 0.19077412513255568, err: 0.00014996962485399769
#   >>> f1 - y: 0.19077412513255568, err: 0.00014996962485399769
#   >>> rmse - y: 2.7262599042150355, err: 0.0037286985244672608
#   >>> mae - y: 2.389348800070681, err: 0.0027097626936139576
# [ClusteredUserBasedCF._clusterize] total 1.12 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.69 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.81 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 8.92 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.01 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.84 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.85 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 9.00 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.05 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.86 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.91 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 9.14 seconds have spent
#
# >>> results for value 7:
#   >>> time - y: 9.020211140314737, err: 0.08978148754770235
#   >>> prec - y: 0.1959349593495935, err: 0.0007261448774893639
#   >>> recall - y: 0.1959349593495935, err: 0.0007261448774893639
#   >>> f1 - y: 0.1959349593495935, err: 0.0007261448774893639
#   >>> rmse - y: 2.7214597769655167, err: 0.0025954838399596175
#   >>> mae - y: 2.3893466187054857, err: 0.001170319436829521
# [ClusteredUserBasedCF._clusterize] total 1.21 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.80 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 4.01 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 11.03 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.97 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.85 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.82 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 10.34 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.16 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.72 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.88 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 10.62 seconds have spent
#
# >>> results for value 8:
#   >>> time - y: 10.661456743876139, err: 0.2840932513203577
#   >>> prec - y: 0.19604100388829973, err: 0.0017581944313108343
#   >>> recall - y: 0.19604100388829973, err: 0.0017581944313108343
#   >>> f1 - y: 0.19604100388829973, err: 0.0017581944313108343
#   >>> rmse - y: 2.7184281517157465, err: 0.002363070392001466
#   >>> mae - y: 2.3895400929446313, err: 0.0020075903819993047
# [ClusteredUserBasedCF._clusterize] total 1.20 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.92 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 4.12 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 11.67 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.87 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.88 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.75 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 11.68 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.98 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.84 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.82 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 11.47 seconds have spent
#
# >>> results for value 9:
# ...
#
# [ClusteredItemBasedCF.predict_all] total 10.82 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.16 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.18 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.34 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 10.74 seconds have spent
#
# >>> results for value 16:
#   >>> time - y: 10.797606388727823, err: 0.03773283036817992
#   >>> prec - y: 0.18264404383174268, err: 0.00019995949980530846
#   >>> recall - y: 0.18264404383174268, err: 0.00019995949980530846
#   >>> f1 - y: 0.18264404383174263, err: 0.00019995949980532152
#   >>> rmse - y: 2.6239888771145576, err: 0.0015551696853941131
#   >>> mae - y: 2.3230921049299535, err: 0.0012825176849701376
# [ClusteredItemBasedCF._clusterize] total 1.31 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.80 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.12 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 11.39 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.17 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.98 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.14 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 11.51 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.23 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.24 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.47 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 11.37 seconds have spent
#
# >>> results for value 17:
#   >>> time - y: 11.426308075586954, err: 0.061790278305518226
#   >>> prec - y: 0.18267939201131142, err: 0.001472793683704463
#   >>> recall - y: 0.18267939201131142, err: 0.001472793683704463
#   >>> f1 - y: 0.18267939201131145, err: 0.0014727936837044746
#   >>> rmse - y: 2.618082611671125, err: 0.000513937919302972
#   >>> mae - y: 2.3183442192728414, err: 0.0008878705032852317
# [ClusteredItemBasedCF._clusterize] total 1.27 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.76 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.03 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 12.08 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.18 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.47 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 13.65 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 12.17 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.28 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.91 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 15.20 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 12.32 seconds have spent
#
# >>> results for value 18:
#   >>> time - y: 12.19053856531779, err: 0.09914766313612819
#   >>> prec - y: 0.1775892541534111, err: 0.0070135634218372
#   >>> recall - y: 0.1775892541534111, err: 0.0070135634218372
#   >>> f1 - y: 0.1775892541534111, err: 0.0070135634218372
#   >>> rmse - y: 2.6251870902401664, err: 0.009002734571001852
#   >>> mae - y: 2.3264859516973626, err: 0.011511241161662427
# [ClusteredItemBasedCF._clusterize] total 1.20 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.99 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.19 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 12.74 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.12 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.10 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.22 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 12.72 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.18 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.02 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.19 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 12.76 seconds have spent
#
# >>> results for value 19:
#   >>> time - y: 12.740280230840048, err: 0.01867048907350456
#   >>> prec - y: 0.18055850123718628, err: 0.0012132203818826862
#   >>> recall - y: 0.18055850123718628, err: 0.0012132203818826862
#   >>> f1 - y: 0.18055850123718628, err: 0.0012132203818826862
#   >>> rmse - y: 2.611346384432647, err: 0.0012475440634062793
#   >>> mae - y: 2.312581714565454, err: 0.0017144770309377305
# [ClusteredItemBasedCF._clusterize] total 1.00 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.62 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 13.62 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 13.29 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.14 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.94 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.08 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 13.35 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.23 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.27 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.50 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 13.40 seconds have spent
#
# >>> results for value 20:
#   >>> time - y: 13.348627090454102, err: 0.04610146593427654
#   >>> prec - y: 0.17999293036408626, err: 0.001969372679700828
#   >>> recall - y: 0.17999293036408626, err: 0.001969372679700828
#   >>> f1 - y: 0.17999293036408626, err: 0.001969372679700828
#   >>> rmse - y: 2.611318623841814, err: 0.0032314999193520707
#   >>> mae - y: 2.313114446491689, err: 0.00394098171964354
# [ClusteredItemBasedCF._clusterize] total 1.25 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.66 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 13.91 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 14.10 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.18 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.13 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.31 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 14.13 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.17 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.24 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.41 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 18.19 seconds have spent
#
# >>> results for value 21:
#   >>> time - y: 15.473223447799683, err: 1.9229352061865082
#   >>> prec - y: 0.17465535524920464, err: 0.005854580590389077
#   >>> recall - y: 0.17465535524920464, err: 0.005854580590389077
#   >>> f1 - y: 0.17465535524920464, err: 0.005854580590389077
#   >>> rmse - y: 2.6128114866707914, err: 0.008177450851940531
#   >>> mae - y: 2.3179312797066447, err: 0.010691975397863488
# [ClusteredItemBasedCF._clusterize] total 1.47 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.85 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 15.32 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 14.70 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.20 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.08 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.28 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 14.76 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.13 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.22 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.35 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 14.74 seconds have spent
#
# >>> results for value 22:
#   >>> time - y: 14.736952066421509, err: 0.02497560339974665
#   >>> prec - y: 0.17914457405443618, err: 0.001837425439146971
#   >>> recall - y: 0.17914457405443618, err: 0.001837425439146971
#   >>> f1 - y: 0.17914457405443618, err: 0.001837425439146971
#   >>> rmse - y: 2.6053707839030804, err: 0.0009362956372729563
#   >>> mae - y: 2.309048573136807, err: 0.0011321336687054207
# [ClusteredItemBasedCF._clusterize] total 1.22 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.84 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.06 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 15.47 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.23 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.36 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.59 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 15.37 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.23 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.78 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.01 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 15.40 seconds have spent
#
# >>> results for value 23:
#   >>> time - y: 15.411470413208008, err: 0.042197353854089896
#   >>> prec - y: 0.17338282078472958, err: 0.005632020026328485
#   >>> recall - y: 0.17338282078472958, err: 0.005632020026328485
#   >>> f1 - y: 0.17338282078472958, err: 0.005632020026328485
#   >>> rmse - y: 2.612293644851501, err: 0.007093793411602821
#   >>> mae - y: 2.3192576004408587, err: 0.009459780802314103
# [ClusteredItemBasedCF._clusterize] total 1.12 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.20 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.31 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 16.29 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.19 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.84 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.02 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 15.93 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.27 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.39 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.66 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 17.73 seconds have spent
#
# >>> results for value 24:
#   >>> time - y: 16.649572213490803, err: 0.7771703195143462
#   >>> prec - y: 0.18020501944149878, err: 0.0019977194981894396
#   >>> recall - y: 0.18020501944149878, err: 0.0019977194981894396
#   >>> f1 - y: 0.18020501944149878, err: 0.0019977194981894396
#   >>> rmse - y: 2.603033998886153, err: 0.0022547639837755874
#   >>> mae - y: 2.3080818503152982, err: 0.002604770917756069
# [ClusteredItemBasedCF._clusterize] total 1.28 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.00 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.28 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 16.66 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.26 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.16 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.41 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 16.72 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.25 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.25 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.50 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 16.85 seconds have spent
#
# >>> results for value 25:
#   >>> time - y: 16.74184234937032, err: 0.07907083677174445
#   >>> prec - y: 0.17783669141039238, err: 0.002013915805336744
#   >>> recall - y: 0.17783669141039238, err: 0.002013915805336744
#   >>> f1 - y: 0.17783669141039238, err: 0.002013915805336744
#   >>> rmse - y: 2.6014209060536952, err: 0.0011609616517884434
#   >>> mae - y: 2.3069835417044464, err: 0.0014027082755079807
# [ClusteredItemBasedCF._clusterize] total 1.18 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.29 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.47 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 17.41 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.25 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.75 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.00 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 17.32 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.23 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.09 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.32 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 17.49 seconds have spent
#
# >>> results for value 26:
#   >>> time - y: 17.408170461654663, err: 0.07190766470259832
#   >>> prec - y: 0.17398373983739837, err: 0.006517115405580203
#   >>> recall - y: 0.17398373983739837, err: 0.006517115405580203
#   >>> f1 - y: 0.17398373983739837, err: 0.006517115405580203
#   >>> rmse - y: 2.6076492382209273, err: 0.009750085972455028
#   >>> mae - y: 2.3157549878161796, err: 0.013079585129655976
# [ClusteredItemBasedCF._clusterize] total 1.14 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.90 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.04 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 17.95 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.27 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.03 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.30 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 18.99 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.31 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 14.30 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 15.61 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 18.00 seconds have spent
#
# >>> results for value 27:
#   >>> time - y: 18.312276124954224, err: 0.47910931773340654
#   >>> prec - y: 0.1780487804878049, err: 0.002849422872225747
#   >>> recall - y: 0.1780487804878049, err: 0.002849422872225747
#   >>> f1 - y: 0.1780487804878049, err: 0.002849422872225747
#   >>> rmse - y: 2.6016716492800764, err: 0.003416121119544472
#   >>> mae - y: 2.307424294848311, err: 0.004403587002669563
# [ClusteredItemBasedCF._clusterize] total 1.22 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.31 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.52 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 18.55 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.34 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.30 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.64 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 18.60 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.26 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.33 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.59 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 18.56 seconds have spent
#
# >>> results for value 28:
#   >>> time - y: 18.569020589192707, err: 0.01948524787009606
#   >>> prec - y: 0.17444326617179215, err: 0.0008998177491239208
#   >>> recall - y: 0.17444326617179215, err: 0.0008998177491239208
#   >>> f1 - y: 0.17444326617179215, err: 0.0008998177491239208
#   >>> rmse - y: 2.600612083230939, err: 0.000215370214105573
#   >>> mae - y: 2.307147740162201, err: 0.00025936211037661596
# [ClusteredItemBasedCF._clusterize] total 1.24 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.74 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 13.99 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 19.15 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.17 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.06 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.23 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 19.26 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.19 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.16 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.35 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 19.22 seconds have spent
#
# >>> results for value 29:
#   >>> time - y: 19.212402900060017, err: 0.045311916068563426
#   >>> prec - y: 0.17345351714386711, err: 0.005525407811237458
#   >>> recall - y: 0.17345351714386711, err: 0.005525407811237458
#   >>> f1 - y: 0.17345351714386711, err: 0.005525407811237465
#   >>> rmse - y: 2.6035904973151767, err: 0.007622008894132323
#   >>> mae - y: 2.3111657312258065, err: 0.01138878346854641
