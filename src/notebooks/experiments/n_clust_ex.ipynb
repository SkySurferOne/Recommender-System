# %%
import numpy as np

from src.main.DatasetManager import DatasetManager
from src.main.Evaluator import Evaluator
from src.main.models.ClusteredItemBasedCF import ClusteredItemBasedCF
from src.main.models.ClusteredUserBasedCF import ClusteredUserBasedCF
from src.main.utils.plot_generators import measure_time, gen_plots_with_errbars

# %%
dirname = '/home/damian/Pulpit/Warsztat/CoML/recomm_project/data/'
dm = DatasetManager()

# %%
ml100k_filename = dirname + 'ml-100k/ua.base'
ml100k_filename_test = dirname + 'ml-100k/ua.test'

train = dm.load_csv(ml100k_filename, realative=False)
test = dm.load_csv(ml100k_filename_test, realative=False)

user_item = DatasetManager.transform_to_user_item_mat(train, verbose=True)
user_item_test = DatasetManager.transform_to_user_item_mat(test, verbose=True)
# Out:
# User number: 943, item number: 1682
# User number: 943, item number: 1664

# %%
# eval models across different cluster number

models = [
    { 'model': ClusteredUserBasedCF, 'name': 'ClustUsrBasedCF'},
    { 'model': ClusteredItemBasedCF, 'name': 'ClustItmBasedCF'},
]

n_range = np.arange(1, 11)
repeat = 3

plots = [
    {'key': 'fit', 'name': 'Fitting time x n-clusters', 'xlabel': 'n', 'ylabel': 't [s]'},
    {'key': 'pred', 'name': 'Prediction time x n-clusters', 'xlabel': 'n', 'ylabel': 't [s]'},
    {'key': 'prec', 'name': 'Precision x n-clusters', 'xlabel': 'n', 'ylabel': 'prec'},
    {'key': 'rmse', 'name': 'RMSE x n-clusters', 'xlabel': 'n', 'ylabel': 'rmse'}
]

def func_clust(sink, model_desc, n):
    model_class = model_desc['model']
    model = model_class(n_clusters=n, verbose=True)
    
    measure_time(lambda: model.fit(user_item), sink['fit'])
    pred = measure_time(lambda: model.predict_all(), sink['pred'])
    
    recomm, _ = model._recommend_all(pred)
    recomm = model._transform_recomm(recomm)
    
    eval = Evaluator(user_item_test).eval(recomm, pred)
    
    sink['prec'].append(eval['prec'])
    sink['rmse'].append(eval['rmse'])

# %%
gen_plots_with_errbars(plots, models, n_range, func_clust, repeat, verbose=True)
# Out:
# (0) started calculation for ClustUsrBasedCF case
# [ClusteredUserBasedCF._clusterize] total 0.21 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 6.27 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 6.49 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 27.81 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.24 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 6.55 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 6.79 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 26.17 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.17 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 6.06 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 6.23 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.57 seconds have spent
#
# >>> results for value 1:
#   >>> fit - y: 6.502177794774373, err: 0.22897476869656158
#   >>> pred - y: 26.51809247334798, err: 0.9448609340336043
#   >>> prec - y: 0.22492046659597031, err: 0.0
#   >>> rmse - y: 2.605186005754215, err: 0.0
# [ClusteredUserBasedCF._clusterize] total 0.60 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 3.65 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 4.25 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 27.19 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.68 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 3.88 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 4.56 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 27.14 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 0.79 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 4.51 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 5.30 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 27.46 seconds have spent
#
# >>> results for value 2:
#   >>> fit - y: 4.701621452967326, err: 0.43886074364140487
#   >>> pred - y: 27.26449942588806, err: 0.1400903395971386
#   >>> prec - y: 0.22184517497348888, err: 0.0004499088745619669
#   >>> rmse - y: 2.673515864722257, err: 2.219025800449909e-05
# [ClusteredUserBasedCF._clusterize] total 1.01 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.92 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.93 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.65 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.10 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.86 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.96 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.47 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.09 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.71 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.80 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.36 seconds have spent
#
# >>> results for value 3:
#   >>> fit - y: 3.8988242944081626, err: 0.06958966699445893
#   >>> pred - y: 25.491109768549602, err: 0.11978386360703945
#   >>> prec - y: 0.22018381053375755, err: 0.0009258254403470314
#   >>> rmse - y: 2.703289446810199, err: 0.0007892511550002871
# [ClusteredUserBasedCF._clusterize] total 1.36 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.73 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 4.09 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 29.17 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.48 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.67 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 4.15 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.46 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.15 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.56 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.72 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.40 seconds have spent
#
# >>> results for value 4:
#   >>> fit - y: 3.9861759344736734, err: 0.19321335081290442
#   >>> pred - y: 26.678786595662434, err: 1.764422853180066
#   >>> prec - y: 0.21866383881230114, err: 0.0005677758361332287
#   >>> rmse - y: 2.706195178581981, err: 0.00037378567243677056
# [ClusteredUserBasedCF._clusterize] total 1.55 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.99 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.55 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.00 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.38 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.98 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.37 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.03 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.33 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 2.08 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.41 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 24.95 seconds have spent
#
# >>> results for value 5:
#   >>> fit - y: 3.4418031374613443, err: 0.07656111823835983
#   >>> pred - y: 24.995671192804974, err: 0.03288052767647836
#   >>> prec - y: 0.21686108165429477, err: 0.0005195100196783025
#   >>> rmse - y: 2.7392058998617532, err: 0.0017113621502041988
# [ClusteredUserBasedCF._clusterize] total 1.45 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.98 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.43 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 24.49 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.42 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.93 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.35 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.67 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.63 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.92 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.55 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 26.80 seconds have spent
#
# >>> results for value 6:
#   >>> fit - y: 3.443701187769572, err: 0.08266914081326185
#   >>> pred - y: 25.65260648727417, err: 0.9423246164495886
#   >>> prec - y: 0.21739130434782608, err: 0.0006537024393392367
#   >>> rmse - y: 2.742210394857755, err: 0.001280333319962406
# [ClusteredUserBasedCF._clusterize] total 1.57 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.84 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.41 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.06 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.64 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.92 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.56 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 26.39 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.43 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.75 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.18 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.80 seconds have spent
#
# >>> results for value 7:
#   >>> fit - y: 3.3833072980244956, err: 0.15449798594694228
#   >>> pred - y: 25.747490962346394, err: 0.5443006323776871
#   >>> prec - y: 0.21329091551785084, err: 0.0013226077719243382
#   >>> rmse - y: 2.7521699525277143, err: 0.001980696449480279
# [ClusteredUserBasedCF._clusterize] total 1.94 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.68 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.62 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.78 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.68 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.87 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.55 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 26.94 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.53 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.72 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.25 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 26.18 seconds have spent
#
# >>> results for value 8:
#   >>> fit - y: 3.4741884072621665, err: 0.15870264823707567
#   >>> pred - y: 26.3005112806956, err: 0.48399507693570326
#   >>> prec - y: 0.21180629197596323, err: 0.001439326480841454
#   >>> rmse - y: 2.7496598508781296, err: 0.002148418960007195
# [ClusteredUserBasedCF._clusterize] total 1.63 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.66 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.29 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.56 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.60 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.69 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.29 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 26.32 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.68 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.65 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.33 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.91 seconds have spent
#
# >>> results for value 9:
#   >>> fit - y: 3.301642974217733, err: 0.019040696123959557
#   >>> pred - y: 25.929107348124187, err: 0.30737516510334195
#   >>> prec - y: 0.2108165429480382, err: 0.0003463400131188646
#   >>> rmse - y: 2.7527692214675046, err: 0.002892765039800274
# [ClusteredUserBasedCF._clusterize] total 1.75 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.98 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.73 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 24.43 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.61 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.82 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.42 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.86 seconds have spent
#
# [ClusteredUserBasedCF._clusterize] total 1.72 seconds have spent
#
# [ClusteredUserBasedCF._calc_sim] total 1.72 seconds have spent
#
# [ClusteredUserBasedCF.fit] total 3.44 seconds have spent
#
# [ClusteredUserBasedCF.predict_all] total 25.15 seconds have spent
#
# >>> results for value 10:
#   >>> fit - y: 3.531886577606201, err: 0.1420329957524546
#   >>> pred - y: 25.145336945851643, err: 0.5853218636296921
#   >>> prec - y: 0.21382113821138213, err: 0.0034311412929995807
#   >>> rmse - y: 2.7513759082664264, err: 0.003932132912751864
# (1) started calculation for ClustItmBasedCF case
# [ClusteredItemBasedCF._clusterize] total 0.28 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 25.57 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 25.85 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 7.04 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 0.17 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 25.98 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 26.15 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 7.02 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 0.17 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 25.77 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 25.94 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 7.07 seconds have spent
#
# >>> results for value 1:
#   >>> fit - y: 25.983745098114014, err: 0.1267718257202425
#   >>> pred - y: 7.041937828063965, err: 0.019462726131599252
#   >>> prec - y: 0.20434782608695654, err: 0.0
#   >>> rmse - y: 2.735125231657934, err: 0.0
# [ClusteredItemBasedCF._clusterize] total 0.79 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 18.23 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 19.02 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.60 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 0.64 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 17.66 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 18.30 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.46 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 0.64 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 18.04 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 18.68 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.50 seconds have spent
#
# >>> results for value 2:
#   >>> fit - y: 18.66951545079549, err: 0.29283975414240937
#   >>> pred - y: 6.517444292704265, err: 0.058727858094187305
#   >>> prec - y: 0.18642629904559915, err: 0.0
#   >>> rmse - y: 2.7103605722562065, err: 0.0
# [ClusteredItemBasedCF._clusterize] total 1.22 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.71 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 13.93 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.23 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 0.88 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.35 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.22 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.47 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 0.97 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.61 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.58 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.48 seconds have spent
#
# >>> results for value 3:
#   >>> fit - y: 14.244537750879923, err: 0.264824646371419
#   >>> pred - y: 6.395158449808757, err: 0.1143694854047903
#   >>> prec - y: 0.17525627430187343, err: 0.0005073418202335524
#   >>> rmse - y: 2.6818929958713205, err: 0.0042904531317407065
# [ClusteredItemBasedCF._clusterize] total 1.55 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.05 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.60 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.49 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.13 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 13.59 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.72 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.55 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.20 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 14.00 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 15.20 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 7.22 seconds have spent
#
# >>> results for value 4:
#   >>> fit - y: 14.84080425898234, err: 0.2583718078079118
#   >>> pred - y: 6.752307732899983, err: 0.3314174486466711
#   >>> prec - y: 0.1880876634853305, err: 9.997974990266076e-05
#   >>> rmse - y: 2.6812691873740597, err: 0.0024306013811844374
# [ClusteredItemBasedCF._clusterize] total 1.49 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 14.62 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 16.12 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 7.07 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.30 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.08 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 13.38 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.52 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.28 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.75 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 14.03 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.57 seconds have spent
#
# >>> results for value 5:
#   >>> fit - y: 14.509799321492514, err: 1.1681438628298115
#   >>> pred - y: 6.723790645599365, err: 0.24832673329874125
#   >>> prec - y: 0.18154825026511134, err: 0.003004387325680559
#   >>> rmse - y: 2.684140092725786, err: 0.006436793025472951
# [ClusteredItemBasedCF._clusterize] total 1.41 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.23 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 13.65 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.59 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.44 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 11.35 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 12.79 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.52 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.36 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.60 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 13.96 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.43 seconds have spent
#
# >>> results for value 6:
#   >>> fit - y: 13.463779131571451, err: 0.4965272641775873
#   >>> pred - y: 6.511082251866658, err: 0.0659193302635267
#   >>> prec - y: 0.18126546482856132, err: 0.0010963635503195982
#   >>> rmse - y: 2.657790791971179, err: 0.01683159165808209
# [ClusteredItemBasedCF._clusterize] total 1.49 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 12.09 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 13.58 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.55 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.41 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 10.85 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 12.26 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.61 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.44 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 11.70 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 13.14 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.55 seconds have spent
#
# >>> results for value 7:
#   >>> fit - y: 12.991642713546753, err: 0.5497088152635232
#   >>> pred - y: 6.5694343249003095, err: 0.029877719265726643
#   >>> prec - y: 0.17914457405443618, err: 0.006843137335488305
#   >>> rmse - y: 2.6226478005162184, err: 0.0027503812353151668
# [ClusteredItemBasedCF._clusterize] total 1.59 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 10.95 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 12.55 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.48 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.69 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 10.27 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 11.96 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.31 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.58 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 9.79 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 11.37 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.28 seconds have spent
#
# >>> results for value 8:
#   >>> fit - y: 11.958333015441895, err: 0.47946264477540385
#   >>> pred - y: 6.358612457911174, err: 0.08793999765997304
#   >>> prec - y: 0.17773064687168613, err: 0.0015170918157564515
#   >>> rmse - y: 2.6257250154424407, err: 0.00596917929659535
# [ClusteredItemBasedCF._clusterize] total 1.72 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 10.23 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 11.95 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.14 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.63 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 9.96 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 11.59 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.12 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.59 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 10.04 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 11.64 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.19 seconds have spent
#
# >>> results for value 9:
#   >>> fit - y: 11.725209633509317, err: 0.15996693049182975
#   >>> pred - y: 6.150812943776448, err: 0.02939370584674905
#   >>> prec - y: 0.1817956875220926, err: 0.0031651921393458654
#   >>> rmse - y: 2.6198439026383222, err: 0.005367795663757703
# [ClusteredItemBasedCF._clusterize] total 1.77 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 10.18 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 11.94 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.14 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.73 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 9.19 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 10.92 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.19 seconds have spent
#
# [ClusteredItemBasedCF._clusterize] total 1.65 seconds have spent
#
# [ClusteredItemBasedCF._calc_sim] total 9.30 seconds have spent
#
# [ClusteredItemBasedCF.fit] total 10.95 seconds have spent
#
# [ClusteredItemBasedCF.predict_all] total 6.25 seconds have spent
#
# >>> results for value 10:
#   >>> fit - y: 11.271918853123983, err: 0.47526943265477767
#   >>> pred - y: 6.193318128585815, err: 0.04321798295858781
#   >>> prec - y: 0.1806291975963238, err: 0.003394897759927313
#   >>> rmse - y: 2.6102018673852356, err: 0.004012330121207613
